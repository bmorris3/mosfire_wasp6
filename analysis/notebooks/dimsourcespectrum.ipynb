# %%
# %pylab inline
import pyfits
import numpy as np
from matplotlib import pyplot as plt
import sys
sys.path.append('../')
import photPack2
from astropy.time import Time

wasp6paths_nodsub_odd = ["%s%04d%s" % ('/local/tmp/mosfire/2014sep18_analysis/m140918_', i, \
                                       'n.fits') for i in range(374,629,2)]

sumimages = np.zeros_like(pyfits.getdata(wasp6paths_nodsub_odd[0]))

for image in wasp6paths_nodsub_odd:
    sumimages += pyfits.getdata(image)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fig, ax = plt.subplots(figsize=(14,8))
ax.plot(np.sum(sumimages,axis=1))
ax.set_xlabel('Row')
ax.set_ylabel('Counts')
ax.set_xlim([100,1900])
ax.set_ylim([0.5e7,1.5e7])
ax.set_title('Nod subtracted frame')
plt.show()
plt.show()
